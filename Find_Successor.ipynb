# %% [markdown]
# <a href="https://colab.research.google.com/github/iamchemist/Algo-DS/blob/main/Find_Successor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is an input class. Do not edit.
class BinaryTree:
    def __init__(self, value, left=None, right=None, parent=None):
        self.value = value
        self.left = left
        self.right = right
        self.parent = parent

def findSuccessor(tree, node):
    # Write your code here.
    i=0
    target=[]
    helper(tree,target)
    while(i<len(target)-1):
        if target[i]==node:
            return target[i+1]
        i+=1
    return None
def helper(tree,target):
    if tree is None:
        return None
    else:
        helper(tree.left,target)
        target.append(tree)
        helper(tree.right,target)
    return None

# %%
# This is an input class. Do not edit.
class BinaryTree:
    def __init__(self, value, left=None, right=None, parent=None):
        self.value = value
        self.left = left
        self.right = right
        self.parent = parent


def findSuccessor(tree, node):
    # Write your code here.
    if(node.right is not None):
        return getleftmostchild(node.right)
    else:
        return getfirstparent(node)
    return None

def getleftmostchild(trees):
    tree=trees
    while(tree.left is not None):
        tree=tree.left
    return tree

def getfirstparent(tree):
    current=tree.parent
    while(tree.parent is not None and tree.parent.right==tree):
        tree=tree.parent
    return tree.parent
