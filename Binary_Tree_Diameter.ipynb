# %% [markdown]
# <a href="https://colab.research.google.com/github/iamchemist/Algo-DS/blob/main/Binary_Tree_Diameter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is an input class. Do not edit.
class BinaryTree:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right


def binaryTreeDiameter(tree):
    # Write your code here.
    target=[0]
    helper(tree,target)
    return target[0]

def helper(tree,target):
    if tree is None:
        return 0
    else:
        if(tree.left is None and tree.right is None):
            return 1
        lv=helper(tree.left,target)
        rv=helper(tree.right,target)
        if target[0]<(lv+rv):
            target[0]=lv+rv
        lv+=1
        rv+=1
    return max(lv,rv)
