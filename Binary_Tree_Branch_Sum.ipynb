# %% [markdown]
# <a href="https://colab.research.google.com/github/iamchemist/Algo-DS/blob/Trees/Binary_Tree_Branch_Sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is the class of the input root. Do not edit it.
class BinaryTree:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


def branchSums(root):
    # Write your code here.
    target=[]
    i=0
    helper(root,target,i)
    return target

def helper(root,target,i):
    if root is None:
        return None
    else:
        i+=root.value
        if (root.left is  None and root.right is None):
            target.append(i)
        helper(root.left,target,i)
        helper(root.right,target,i)
    return None
