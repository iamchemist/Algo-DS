# %% [markdown]
# <a href="https://colab.research.google.com/github/iamchemist/Algo-DS/blob/main/Evaluate_Expression_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is an input class. Do not edit.
import math
class BinaryTree:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right


def evaluateExpressionTree(tree):
    # Write your code here.
    target=[]
    helper(tree, target)
    return target[0]

def helper(tree,target):
    if tree is None:
        return None
    else:
        helper(tree.left,target)
        helper(tree.right,target)
        if(tree.value not in {-1,-2,-3,-4}):
            target.append(tree.value)
            return None
        elif(tree.value==-4):
            i=target[-1]*target[-2]
            del target[-2:]
            target.append(i)
            return None
        elif(tree.value==-3):
            i=int(target[-2]/target[-1])
            del target[-2:]
            target.append(i)
            return None
        elif(tree.value==-2):
            i=target[-2]-target[-1]
            del target[-2:]
            target.append(i)
            return None
        elif(tree.value==-1):
            i=target[-2]+target[-1]
            del target[-2:]
            target.append(i)
    return None
