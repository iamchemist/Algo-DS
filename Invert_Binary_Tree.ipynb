# %% [markdown]
# <a href="https://colab.research.google.com/github/iamchemist/Algo-DS/blob/main/Invert_Binary_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def invertBinaryTree(tree):
    # Write your code here.
    return helper(tree)

def helper(tree):
    if (tree is None):
        return None
    else:
        helper(tree.left)
        helper(tree.right)
        if(tree.left is not None or tree.right is not None):
            temp=tree.left
            tree.left=tree.right
            tree.right=temp
        return tree

# This is the class of the input binary tree.
class BinaryTree:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
